# %%
import pandas as pd

# %%
userData = pd.read_csv("GeneratedData/user_info_final_fixed.csv")
userData
# Out:
#       User ID              Name                         Email  Created At  \
# 0        2277     Kelly Roberts     kelly.roberts@example.com  2023-10-05
# 1        1495     Brad Gonzalez     brad.gonzalez@example.com  2024-04-22
# 2        4716       Teresa Gill       teresa.gill@example.com  2023-09-15
# 3        6768  Kathryn Sullivan  kathryn.sullivan@example.com  2024-05-03
# 4        9693      Rachel Black      rachel.black@example.com  2022-11-02
# ...       ...               ...                           ...         ...
# 9995     3048      Nicole Mejia      nicole.mejia@example.com  2024-02-21
# 9996     9405      Adriana Owen      adriana.owen@example.com  2021-07-02
# 9997     9097     Kevin Charles     kevin.charles@example.com  2022-08-22
# 9998     4844      Alex Dickson      alex.dickson@example.com  2022-01-18
# 9999     9105        Jason Mora        jason.mora@example.com  2022-05-15
#
#       Gender   Birthdate
# 0       Male  1977-12-09
# 1     Female  2003-07-06
# ...

# %%
userData.sort_values(by="User ID",inplace=True)
userData
# Out:
#       User ID             Name                        Email  Created At  \
# 5843        1   Luis Rodriguez   luis.rodriguez@example.com  2020-08-04
# 7823        2     Renee Gibson     renee.gibson@example.com  2020-08-15
# 7158        3  Jennifer Rivera  jennifer.rivera@example.com  2023-09-04
# 6863        4     Lisa Collins     lisa.collins@example.com  2024-04-27
# 8507        5   Nicholas Mccoy   nicholas.mccoy@example.com  2023-01-29
# ...       ...              ...                          ...         ...
# 9014     9996   William Thomas   william.thomas@example.com  2021-02-26
# 6958     9997  Christine Keith  christine.keith@example.com  2021-08-30
# 1647     9998    Daniel Miller    daniel.miller@example.com  2023-07-13
# 7663     9999    Kevin Simmons    kevin.simmons@example.com  2020-11-14
# 6346    10000  Kristen Hancock  kristen.hancock@example.com  2022-10-30
#
#       Gender   Birthdate
# 5843    Male  1961-04-13
# 7823    Male  1980-10-02
# ...

# %%
userData["Password"] = "password123"
userData["UserType"] = "customer"
userData
# Out:
#       User ID             Name                        Email  Created At  \
# 5843        1   Luis Rodriguez   luis.rodriguez@example.com  2020-08-04
# 7823        2     Renee Gibson     renee.gibson@example.com  2020-08-15
# 7158        3  Jennifer Rivera  jennifer.rivera@example.com  2023-09-04
# 6863        4     Lisa Collins     lisa.collins@example.com  2024-04-27
# 8507        5   Nicholas Mccoy   nicholas.mccoy@example.com  2023-01-29
# ...       ...              ...                          ...         ...
# 9014     9996   William Thomas   william.thomas@example.com  2021-02-26
# 6958     9997  Christine Keith  christine.keith@example.com  2021-08-30
# 1647     9998    Daniel Miller    daniel.miller@example.com  2023-07-13
# 7663     9999    Kevin Simmons    kevin.simmons@example.com  2020-11-14
# 6346    10000  Kristen Hancock  kristen.hancock@example.com  2022-10-30
#
#       Gender   Birthdate     Password  UserType
# 5843    Male  1961-04-13  password123  customer
# ...

# %%
userData.to_excel("Integration/Users.xlsx",index=False)

# %%
phone = userData[["User ID"]].copy()
phone
# Out:
#       User ID
# 5843        1
# 7823        2
# 7158        3
# 6863        4
# 8507        5
# ...       ...
# 9014     9996
# 6958     9997
# 1647     9998
# 7663     9999
# 6346    10000
#
# [10000 rows x 1 columns]

# %%
phone["PhoneNumber"] = "01000000000"
phone
# Out:
#       User ID  PhoneNumber
# 5843        1  01000000000
# 7823        2  01000000000
# 7158        3  01000000000
# 6863        4  01000000000
# 8507        5  01000000000
# ...       ...          ...
# 9014     9996  01000000000
# 6958     9997  01000000000
# 1647     9998  01000000000
# 7663     9999  01000000000
# 6346    10000  01000000000
#
# [10000 rows x 2 columns]

# %%
phone.to_excel("Integration/Phones.xlsx",index=False)

# %%
Businesses = pd.read_csv("GeneratedData/egyptian_restaurants_refined.csv")
Businesses
# Out:
#      Restaurant ID    Restaurant Name          Category             City  \
# 0                1           30 North              Cafe       Alexandria
# 1                2             Indira     Asian Cuisine       Alexandria
# 2                3             Seoudi     Casual Dining            Cairo
# 3                4               Paul            Bakery       Alexandria
# 4                5              Wel3a             Grill  Sharm El Sheikh
# ..             ...                ...               ...              ...
# 995            996       Koshary Hend           Koshary             Giza
# 996            997        Abou Haidar        Sandwiches         Hurghada
# 997            998    Maison de Curry            Indian            Cairo
# 998            999           Arabiata  Egyptian Cuisine            Cairo
# 999           1000  Koshary El Tahrir           Koshary       Alexandria
#
#            Area  Longitude   Latitude
# 0         Gleem  29.901193  31.186937
# ...

# %%
cats = Businesses["Category"].unique()
categories = pd.DataFrame({"ID": range(1, len(cats) + 1), "Category": cats})
categories
# Out:
#     ID              Category
# 0    1                  Cafe
# 1    2         Asian Cuisine
# 2    3         Casual Dining
# 3    4                Bakery
# 4    5                 Grill
# 5    6        Latin American
# 6    7                Indian
# 7    8        American Diner
# 8    9         Mediterranean
# 9   10              Shawarma
# 10  11               Seafood
# 11  12         Fried Chicken
# 12  13              European
# 13  14              Lebanese
# 14  15         International
# 15  16           Fine Dining
# 16  17               Burgers
# 17  18      Egyptian Cuisine
# 18  19  Egyptian Street Food
# 19  20               Italian
# 20  21            Sandwiches
# 21  22               Koshary
# 22  23            Steakhouse
# 23  24               Mexican

# %%
categories.to_excel("Integration/Categories.xlsx",index=False)

# %%
categories = pd.read_excel("Integration/Categories.xlsx", engine="openpyxl")

# %%
Businesses = Businesses.merge(categories, on="Category", how="left")
Businesses
# Out:
#      Restaurant ID    Restaurant Name          Category             City  \
# 0                1           30 North              Cafe       Alexandria
# 1                2             Indira     Asian Cuisine       Alexandria
# 2                3             Seoudi     Casual Dining            Cairo
# 3                4               Paul            Bakery       Alexandria
# 4                5              Wel3a             Grill  Sharm El Sheikh
# ..             ...                ...               ...              ...
# 995            996       Koshary Hend           Koshary             Giza
# 996            997        Abou Haidar        Sandwiches         Hurghada
# 997            998    Maison de Curry            Indian            Cairo
# 998            999           Arabiata  Egyptian Cuisine            Cairo
# 999           1000  Koshary El Tahrir           Koshary       Alexandria
#
#            Area  Longitude   Latitude  ID
# 0         Gleem  29.901193  31.186937   1
# ...

# %%
Businesses.rename(columns={"ID":"CategoryID"},inplace=True)
Businesses
# Out:
#      Restaurant ID    Restaurant Name          Category             City  \
# 0                1           30 North              Cafe       Alexandria
# 1                2             Indira     Asian Cuisine       Alexandria
# 2                3             Seoudi     Casual Dining            Cairo
# 3                4               Paul            Bakery       Alexandria
# 4                5              Wel3a             Grill  Sharm El Sheikh
# ..             ...                ...               ...              ...
# 995            996       Koshary Hend           Koshary             Giza
# 996            997        Abou Haidar        Sandwiches         Hurghada
# 997            998    Maison de Curry            Indian            Cairo
# 998            999           Arabiata  Egyptian Cuisine            Cairo
# 999           1000  Koshary El Tahrir           Koshary       Alexandria
#
#            Area  Longitude   Latitude  CategoryID
# ...

# %%
Businesses["UserId"] = 10001
Businesses
# Out:
#      Restaurant ID    Restaurant Name          Category             City  \
# 0                1           30 North              Cafe       Alexandria
# 1                2             Indira     Asian Cuisine       Alexandria
# 2                3             Seoudi     Casual Dining            Cairo
# 3                4               Paul            Bakery       Alexandria
# 4                5              Wel3a             Grill  Sharm El Sheikh
# ..             ...                ...               ...              ...
# 995            996       Koshary Hend           Koshary             Giza
# 996            997        Abou Haidar        Sandwiches         Hurghada
# 997            998    Maison de Curry            Indian            Cairo
# 998            999           Arabiata  Egyptian Cuisine            Cairo
# 999           1000  Koshary El Tahrir           Koshary       Alexandria
#
#            Area  Longitude   Latitude  CategoryID  UserId
# ...

# %%
Businesses.to_excel("Integration/Businesses.xlsx",index=False)

# %%
Reviews = pd.read_csv("GeneratedData/user_restaurant_ratings_corrected.csv")
Reviews
# Out:
#         User ID  Restaurant ID  Rating  \
# 0          3079            831       4
# 1            73            188       2
# 2          8583            514       3
# 3          6466            676       3
# 4          7292            603       2
# ...         ...            ...     ...
# 499995     8387            209       1
# 499996      723             82       4
# 499997     7293            187       1
# 499998     3041            289       4
# 499999     4614              6       2
#
#                                                  Review   createdAt
# 0                            Great food and experience!  2024-04-01
# 1                            Great food and experience!  2023-02-25
# 2               An average experience, nothing special.  2022-12-12
# 3                            Great food and experience!  2024-10-10
# 4       Not well-seasoned, and the portions were small.  2023-04-26
# ...                                                 ...         ...
# ...

# %%
Reviews["createdAt"] = pd.to_datetime(Reviews["createdAt"])

# %%
Reviews = Reviews.sort_values("createdAt").drop_duplicates(subset=["User ID", "Restaurant ID"], keep="last")
Reviews
# Out:
#         User ID  Restaurant ID  Rating  \
# 152678     2144            835       3
# 82906      5086            857       1
# 494315     2144            393       2
# 145953     3991            762       2
# 432289     7751            688       4
# ...         ...            ...     ...
# 370235     6797            767       1
# 264666     1810            482       2
# 477959     6389            984       4
# 65000       112            997       2
# 401284     4537            215       1
#
#                                           Review  createdAt
# 152678                Great food and experience! 2020-03-04
# 82906                 Great food and experience! 2020-03-04
# 494315                Great food and experience! 2020-03-04
# 145953                Great food and experience! 2020-03-04
# 432289                Great food and experience! 2020-03-05
# ...                                          ...        ...
# 370235                Great food and experience! 2025-03-17
# ...

# %%
Reviews.to_excel("Integration/Reviews.xlsx",index=False)

# %%
Offers = pd.read_csv("GeneratedData/restaurant_offers_promotional.csv")
Offers
# Out:
#       Offer ID  Start Date    End Date  Discount Percentage  \
# 0            1  2025-02-21  2025-03-06                   20
# 1            2  2025-01-31  2025-02-25                   15
# 2            3  2025-02-04  2025-02-22                   10
# 3            4  2025-02-22  2025-03-22                   15
# 4            5  2025-01-31  2025-02-27                   15
# ...        ...         ...         ...                  ...
# 4995      4996  2025-02-24  2025-03-14                   10
# 4996      4997  2025-02-12  2025-03-02                    5
# 4997      4998  2025-02-14  2025-03-02                   20
# 4998      4999  2025-02-24  2025-03-26                   15
# 4999      5000  2025-02-26  2025-03-17                   20
#
#                                       Description   Price  Restaurant ID
# 0     Special offer available for a limited time!  110.40            245
# 1     Special offer available for a limited time!   77.35            141
# ...

# %%
Offers.to_excel("Integration/Offers.xlsx",index=False)

# %%
Payments = pd.read_csv("GeneratedData/payments_updated.csv")
Payments
# Out:
#        PaymentId  TotalPrice PaymentDate  UserId  UserId.1  CartId  \
# 0              1      340.94  2023-03-04    3325      3325    3325
# 1              2      257.54  2025-01-31    6033      6033    6033
# 2              3      355.61  2023-08-25    8885      8885    8885
# 3              4      201.69  2024-12-01    9097      9097    9097
# 4              5      119.67  2023-11-16    9190      9190    9190
# ...          ...         ...         ...     ...       ...     ...
# 19995      19996      105.65  2024-04-18    1212      1212    1212
# 19996      19997      441.50  2024-07-30     834       834     834
# 19997      19998      338.09  2024-02-10     373       373     373
# 19998      19999      266.49  2023-07-11    1530      1530    1530
# 19999      20000      376.94  2024-05-12    9317      9317    9317
#
#           PaymentMethod
# 0      Cash on Delivery
# 1            Debit Card
# 2         Bank Transfer
# 3            Debit Card
# 4         Mobile Wallet
# ...

# %%
methods = Payments["PaymentMethod"].unique()
PaymentMethods = pd.DataFrame({"ID": range(1, len(methods) + 1), "PaymentMethod": methods})
PaymentMethods
# Out:
#    ID     PaymentMethod
# 0   1  Cash on Delivery
# 1   2        Debit Card
# 2   3     Bank Transfer
# 3   4     Mobile Wallet
# 4   5       Credit Card

# %%
PaymentMethods.to_excel("Integration/PaymentMethods.xlsx",index=False)

# %%
Payments = Payments.merge(PaymentMethods, on="PaymentMethod", how="left")
Payments
# Out:
#        PaymentId  TotalPrice PaymentDate  UserId  UserId.1  CartId  \
# 0              1      340.94  2023-03-04    3325      3325    3325
# 1              2      257.54  2025-01-31    6033      6033    6033
# 2              3      355.61  2023-08-25    8885      8885    8885
# 3              4      201.69  2024-12-01    9097      9097    9097
# 4              5      119.67  2023-11-16    9190      9190    9190
# ...          ...         ...         ...     ...       ...     ...
# 19995      19996      105.65  2024-04-18    1212      1212    1212
# 19996      19997      441.50  2024-07-30     834       834     834
# 19997      19998      338.09  2024-02-10     373       373     373
# 19998      19999      266.49  2023-07-11    1530      1530    1530
# 19999      20000      376.94  2024-05-12    9317      9317    9317
#
#           PaymentMethod  ID
# 0      Cash on Delivery   1
# 1            Debit Card   2
# 2         Bank Transfer   3
# 3            Debit Card   2
# ...

# %%
Payments.rename(columns={"ID":"PaymentMethodID"},inplace=True)
Payments
# Out:
#        PaymentId  TotalPrice PaymentDate  UserId  UserId.1  CartId  \
# 0              1      340.94  2023-03-04    3325      3325    3325
# 1              2      257.54  2025-01-31    6033      6033    6033
# 2              3      355.61  2023-08-25    8885      8885    8885
# 3              4      201.69  2024-12-01    9097      9097    9097
# 4              5      119.67  2023-11-16    9190      9190    9190
# ...          ...         ...         ...     ...       ...     ...
# 19995      19996      105.65  2024-04-18    1212      1212    1212
# 19996      19997      441.50  2024-07-30     834       834     834
# 19997      19998      338.09  2024-02-10     373       373     373
# 19998      19999      266.49  2023-07-11    1530      1530    1530
# 19999      20000      376.94  2024-05-12    9317      9317    9317
#
#           PaymentMethod  PaymentMethodID
# 0      Cash on Delivery                1
# 1            Debit Card                2
# ...

# %%
Payments.drop(["UserId.1"], axis=1, inplace=True)
Payments
# Out:
#        PaymentId  TotalPrice PaymentDate  UserId  CartId     PaymentMethod  \
# 0              1      340.94  2023-03-04    3325    3325  Cash on Delivery
# 1              2      257.54  2025-01-31    6033    6033        Debit Card
# 2              3      355.61  2023-08-25    8885    8885     Bank Transfer
# 3              4      201.69  2024-12-01    9097    9097        Debit Card
# 4              5      119.67  2023-11-16    9190    9190     Mobile Wallet
# ...          ...         ...         ...     ...     ...               ...
# 19995      19996      105.65  2024-04-18    1212    1212     Bank Transfer
# 19996      19997      441.50  2024-07-30     834     834  Cash on Delivery
# 19997      19998      338.09  2024-02-10     373     373     Mobile Wallet
# 19998      19999      266.49  2023-07-11    1530    1530       Credit Card
# 19999      20000      376.94  2024-05-12    9317    9317        Debit Card
#
#        PaymentMethodID
# 0                    1
# ...

# %%
Payments.drop(["PaymentMethod"], axis=1, inplace=True)
Payments
# Out:
#        PaymentId  TotalPrice PaymentDate  UserId  CartId  PaymentMethodID
# 0              1      340.94  2023-03-04    3325    3325                1
# 1              2      257.54  2025-01-31    6033    6033                2
# 2              3      355.61  2023-08-25    8885    8885                3
# 3              4      201.69  2024-12-01    9097    9097                2
# 4              5      119.67  2023-11-16    9190    9190                4
# ...          ...         ...         ...     ...     ...              ...
# 19995      19996      105.65  2024-04-18    1212    1212                3
# 19996      19997      441.50  2024-07-30     834     834                1
# 19997      19998      338.09  2024-02-10     373     373                4
# 19998      19999      266.49  2023-07-11    1530    1530                5
# 19999      20000      376.94  2024-05-12    9317    9317                2
#
# [20000 rows x 6 columns]

# %%
Payments.to_excel("Integration/Payments.xlsx",index=False)

# %%
Businesses = pd.read_excel("Integration/Businesses.xlsx")
Businesses
# Out:
#      Restaurant ID    Restaurant Name          Category             City  \
# 0                1           30 North              Cafe       Alexandria
# 1                2             Indira     Asian Cuisine       Alexandria
# 2                3             Seoudi     Casual Dining            Cairo
# 3                4               Paul            Bakery       Alexandria
# 4                5              Wel3a             Grill  Sharm El Sheikh
# ..             ...                ...               ...              ...
# 995            996       Koshary Hend           Koshary             Giza
# 996            997        Abou Haidar        Sandwiches         Hurghada
# 997            998    Maison de Curry            Indian            Cairo
# 998            999           Arabiata  Egyptian Cuisine            Cairo
# 999           1000  Koshary El Tahrir           Koshary       Alexandria
#
#            Area  Longitude   Latitude  CategoryID  UserId  Logo
# ...

# %%
len(Businesses["Restaurant Name"].unique()),Businesses["Restaurant Name"].unique()
# Out:
# (48,
#  array(['30 North', 'Indira', 'Seoudi', 'Paul', 'Wel3a', 'Spectra',
#         'Tabla Luna', 'Maison de Curry', 'Mori Sushi', 'Lucille’s',
#         'The Lemon Tree', 'Shawarma El Reem', 'El Doksh', 'Qahwa',
#         'Chicken Fil-A', 'Gaby’s', 'Caracas', 'Hossam El Refaay',
#         'Cilantro', 'Crave', 'Peking', 'El Menoufy', 'Starbucks',
#         'The Smokery', "Butcher's Burger", 'Gad', 'Costa Coffee', 'Zooba',
#         'Kazouza', 'Le Pacha 1901', 'Maison Thomas', 'TBS', 'Abou Haidar',
#         'Arabiata', 'Tamara', 'Makani', 'Fuddruckers', 'El Dahan',
#         "Beano's", 'Koshary El Tahrir', 'Mo Bistro', 'Koshary Hend',
#         'Buffalo Burger', 'Fish Market', 'Sizzler', "Gringo's", 'Pier 88',
#         'Bazooka'], dtype=object))

# %%
def set_logo(name):
    if name == "30 North":
        return "https://images.deliveryhero.io/image/talabat/restaurants/Logo638106121469981275.jpg"
    elif name == "Indira":
        return "https://images.deliveryhero.io/image/talabat/restaurants/INDIRA_Logo_(1)_637108213175288258.jpg"
    elif name == "Seoudi":
        return "https://www.menuegypt.com/restaurants_logos/Seoudi-Market_logo.jpg"
    elif name == "Paul":
        return "https://images.deliveryhero.io/image/talabat/restaurants/PAUL_Logo_637507897556014529.jpg"
    elif name == "Wel3a":
        return "https://images.deliveryhero.io/image/talabat/restaurants/242123208_7257089654_637837435630006779.jpg"
    elif name == "Spectra":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/fcd4e0be-a3a8-11e8-b2ca-0242ac110002.jpg"
    elif name == "Tabla Luna":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/3bfbe396-b72b-4010-851a-3df627fa78fe.jpg"
    elif name == "Maison de Curry":
        return "https://maisondecurry.com/wp-content/uploads/2021/01/Untitled-design-4.png"
    elif name == "Mori Sushi":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/847d3968-4913-472d-9d7a-f3808238aa4c.jpg"
    elif name == "Lucille’s":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/b6ae2ce6-2225-11e8-924e-0242ac110011.jpg"
    elif name == "The Lemon Tree":
        return "https://tltconcepts.com/images/TLT%20concepts-02.png"
    elif name == "Shawarma El Reem":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/566fbf5b-fbca-47bc-beca-39c5e44b78c9.jpg"
    elif name == "El Doksh":
        return "https://www.menuegypt.com/restaurants_logos/EL-DOKSH_logo.JPG"
    elif name == "Qahwa":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/681c0c35-a6df-4b39-8f52-6107fae1fb74.jpg"
    elif name == "Chicken Fil-A":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/6e64f3b4-088b-4509-9f83-2ed97c561b30.jpg"
    elif name == "Gaby’s":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/045ba27b-9971-4131-858d-c7511cf6bf7a.jpg"
    elif name == "Caracas":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/b6af5869-2225-11e8-924e-0242ac110011.jpg"
    elif name == "Hossam El Refaay":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/56f23b68-4be0-43da-909d-3bab3850d276.jpg"
    elif name == "Cilantro":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/71442ce6-a87e-4363-beda-2f421be95590.jpg"
    elif name == "Crave":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/f1cf3046-e33c-4ea3-aaee-18daf9091185.jpg"
    elif name == "Peking":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/a5fda33e-1728-488a-815f-07a22721694c.jpg"
    elif name == "El Menoufy":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/a6b1b371-a3ea-41b9-9d35-75d3971e3141.jpg"
    elif name == "Starbucks":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/5bf90ee7-095c-4969-bb3b-89579f5da213.jpg"
    elif name == "The Smokery":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/ef8936c4-dffe-46a6-84b6-6cd99b5fb091.jpg"
    elif name == "Butcher's Burger":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/a21ffd54-2c9e-4603-a0e8-7dcbf51961e0.jpg"
    elif name == "Gad":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/7ce1525f-bba1-4434-bd64-22a440fb74fb.jpg"
    elif name == "Costa Coffee":
        return "https://images.deliveryhero.io/image/talabat/restaurants/34274616_21055022094_637850236209136741.png"
    elif name == "Zooba":
        return "https://images.deliveryhero.io/image/talabat/restaurants/logo_(1)_637714480280201015.jpg"
    elif name == "Kazouza":
        return "https://images.deliveryhero.io/image/talabat/restaurants/logo638224326679202882.jpg"
    elif name == "Le Pacha 1901":
        return "https://images.deliveryhero.io/image/talabat/restaurants/asd_637334560824228554.jpg"
    elif name == "Maison Thomas":
        return "https://images.deliveryhero.io/image/talabat/restaurants/logo__20220703T153040526637924518482543473.jpg"
    elif name == "TBS":
        return "https://images.deliveryhero.io/image/talabat/restaurants/TBS_Logo_PDF_Origina_637473602580897312.jpg"
    elif name == "Abou Haidar":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/a89ed793-ddee-4910-b3fa-fa7630a3e7bc.jpg"
    elif name == "Arabiata":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/dc567144-2580-11e8-add5-0242ac110011.jpg"
    elif name == "Tamara":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/e94152d7-37c4-4e37-b203-2ecc4301c6c3.jpg"
    elif name == "Makani":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/e5674fff-49f4-4193-b84b-a34b59bcd949.jpg"
    elif name == "Fuddruckers":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/b6ae35d4-2225-11e8-924e-0242ac110011.jpg"
    elif name == "El Dahan":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/85d4c081-ba38-45ff-b851-87a0dfbc5f89.jpg"
    elif name == "Beano's":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/fcdea507-a381-4743-9756-4105fb5f7ce8.jpg"
    elif name == "Koshary El Tahrir":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/b5040d39-1b82-47aa-bfa2-de7331ca1fdb.jpg"
    elif name == "Mo Bistro":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/dc64ff93-2580-11e8-add5-0242ac110011.jpg"
    elif name == "Koshary Hend":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/3833e325-2ce8-418b-a08a-de307378f440.jpg"
    elif name == "Buffalo Burger":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/2c77c312-364e-4434-9abc-9a925c12a83c.jpg"
    elif name == "Fish Market":
        return "https://images.deliveryhero.io/image/talabat/restaurants/logo_(2)_637062210799554345.jpg"
    elif name == "Sizzler":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/37eaf421-7666-4912-8c75-ca812714051c.jpg"
    elif name == "Gringo's":
        return "https://images.deliveryhero.io/image/talabat/restaurants/e7ss_sqp.jpg"
    elif name == "Pier 88":
        return "https://s3-eu-west-1.amazonaws.com/elmenusv5-stg/Normal/fd0966b8-de5b-45ab-ad7e-a20003f7a43b.jpg"
    elif name == "Bazooka":
        return "https://images.deliveryhero.io/image/talabat/restaurants/logo_636908346115897419.jpg"

# %%
Businesses["Logo"] = Businesses["Restaurant Name"].apply(set_logo)

# %%
Businesses
# Out:
#      Restaurant ID    Restaurant Name          Category             City  \
# 0                1           30 North              Cafe       Alexandria
# 1                2             Indira     Asian Cuisine       Alexandria
# 2                3             Seoudi     Casual Dining            Cairo
# 3                4               Paul            Bakery       Alexandria
# 4                5              Wel3a             Grill  Sharm El Sheikh
# ..             ...                ...               ...              ...
# 995            996       Koshary Hend           Koshary             Giza
# 996            997        Abou Haidar        Sandwiches         Hurghada
# 997            998    Maison de Curry            Indian            Cairo
# 998            999           Arabiata  Egyptian Cuisine            Cairo
# 999           1000  Koshary El Tahrir           Koshary       Alexandria
#
#            Area  Longitude   Latitude  CategoryID  UserId  \
# ...

# %%
Businesses.to_excel("Integration/Businesses.xlsx",index=False)

# %%
users = pd.read_excel("Integration/Users.xlsx")
users
# Out:
#        User ID             Name                        Email  Created At  \
# 0            1   Luis Rodriguez   luis.rodriguez@example.com  2020-08-04
# 1            2     Renee Gibson     renee.gibson@example.com  2020-08-15
# 2            3  Jennifer Rivera  jennifer.rivera@example.com  2023-09-04
# 3            4     Lisa Collins     lisa.collins@example.com  2024-04-27
# 4            5   Nicholas Mccoy   nicholas.mccoy@example.com  2023-01-29
# ...        ...              ...                          ...         ...
# 9996      9997  Christine Keith  christine.keith@example.com  2021-08-30
# 9997      9998    Daniel Miller    daniel.miller@example.com  2023-07-13
# 9998      9999    Kevin Simmons    kevin.simmons@example.com  2020-11-14
# 9999     10000  Kristen Hancock  kristen.hancock@example.com  2022-10-30
# 10000    10001            Admin              Admin@admin.com  2022-10-31
#
#        Gender   Birthdate  Password  UserType  \
# ...

# %%
def set_profile(gender):
    if gender == "Male":
        return "https://i.pinimg.com/736x/6e/59/95/6e599501252c23bcf02658617b29c894.jpg"
    elif gender == "Female":
        return "https://i.pinimg.com/736x/d2/9e/52/d29e52c8cfec7320b1fe09c8421c4156.jpg"

# %%
users["ProfilePhoto"] = users["Gender"].apply(set_profile)

# %%
users
# Out:
#        User ID             Name                        Email  Created At  \
# 0            1   Luis Rodriguez   luis.rodriguez@example.com  2020-08-04
# 1            2     Renee Gibson     renee.gibson@example.com  2020-08-15
# 2            3  Jennifer Rivera  jennifer.rivera@example.com  2023-09-04
# 3            4     Lisa Collins     lisa.collins@example.com  2024-04-27
# 4            5   Nicholas Mccoy   nicholas.mccoy@example.com  2023-01-29
# ...        ...              ...                          ...         ...
# 9996      9997  Christine Keith  christine.keith@example.com  2021-08-30
# 9997      9998    Daniel Miller    daniel.miller@example.com  2023-07-13
# 9998      9999    Kevin Simmons    kevin.simmons@example.com  2020-11-14
# 9999     10000  Kristen Hancock  kristen.hancock@example.com  2022-10-30
# 10000    10001            Admin              Admin@admin.com  2022-10-31
#
#        Gender   Birthdate  Password  UserType  \
# ...

# %%
users.to_excel("Integration/Users.xlsx",index=False)

# %%
offers = pd.read_excel("Integration/Offers.xlsx")
offers
# Out:
#       Offer ID  Start Date    End Date  Discount Percentage  \
# 0            1  2025-02-21  2025-03-06                   20
# 1            2  2025-01-31  2025-02-25                   15
# 2            3  2025-02-04  2025-02-22                   10
# 3            4  2025-02-22  2025-03-22                   15
# 4            5  2025-01-31  2025-02-27                   15
# ...        ...         ...         ...                  ...
# 4995      4996  2025-02-24  2025-03-14                   10
# 4996      4997  2025-02-12  2025-03-02                    5
# 4997      4998  2025-02-14  2025-03-02                   20
# 4998      4999  2025-02-24  2025-03-26                   15
# 4999      5000  2025-02-26  2025-03-17                   20
#
#                                       Description   Price  Restaurant ID  \
# 0     Special offer available for a limited time!  110.40            245
# 1     Special offer available for a limited time!   77.35            141
# ...

# %%
Businesses = pd.read_excel("Integration/Businesses.xlsx")
Businesses
# Out:
#      Restaurant ID    Restaurant Name          Category             City  \
# 0                1           30 North              Cafe       Alexandria
# 1                2             Indira     Asian Cuisine       Alexandria
# 2                3             Seoudi     Casual Dining            Cairo
# 3                4               Paul            Bakery       Alexandria
# 4                5              Wel3a             Grill  Sharm El Sheikh
# ..             ...                ...               ...              ...
# 995            996       Koshary Hend           Koshary             Giza
# 996            997        Abou Haidar        Sandwiches         Hurghada
# 997            998    Maison de Curry            Indian            Cairo
# 998            999           Arabiata  Egyptian Cuisine            Cairo
# 999           1000  Koshary El Tahrir           Koshary       Alexandria
#
#            Area  Longitude   Latitude  CategoryID  UserId  \
# ...

# %%
offerImage = pd.read_excel("Integration/offerImages.xlsx")
offerImage
# Out:
#     CategoryID                                         offerImage
# 0            1  https://i.pinimg.com/736x/9f/50/50/9f5050dc654...
# 1            2  https://i.pinimg.com/736x/20/81/fd/2081fd2c0c5...
# 2            3  https://i.pinimg.com/736x/c1/7d/a7/c17da7a1cf1...
# 3            4  https://i.pinimg.com/736x/67/a7/f5/67a7f533f05...
# 4            5  https://i.pinimg.com/736x/6f/cb/28/6fcb2845b97...
# 5            6  https://i.pinimg.com/736x/5a/30/b9/5a30b9c427e...
# 6            7  https://i.pinimg.com/736x/0c/38/2a/0c382afd62c...
# 7            8  https://i.pinimg.com/736x/59/8a/61/598a61af750...
# 8            9  https://i.pinimg.com/736x/07/4f/09/074f094d9c9...
# 9           10  https://i.pinimg.com/736x/06/c7/35/06c7359667d...
# 10          11  https://i.pinimg.com/736x/f8/f9/37/f8f9379893b...
# 11          12  https://i.pinimg.com/736x/45/54/48/45544829a05...
# 12          13  https://i.pinimg.com/736x/d9/e3/af/d9e3af46291...
# ...

# %%
offers_with_category = offers.merge(Businesses, on='Restaurant ID', how='left')

# %%
offers_with_category = offers_with_category.merge(offerImage, on='CategoryID', how='left', suffixes=('', '_category'))

# %%
offers_with_category['OfferImage'] = offers_with_category['OfferImage'].fillna(offers_with_category['offerImage'])

# %%
offers_filled = offers_with_category[["Offer ID","Start Date","End Date","Discount Percentage","Description","Price","OfferImage","Restaurant ID"]]

# %%
offers_filled
# Out:
#       Offer ID  Start Date    End Date  Discount Percentage  \
# 0            1  2025-02-21  2025-03-06                   20
# 1            2  2025-01-31  2025-02-25                   15
# 2            3  2025-02-04  2025-02-22                   10
# 3            4  2025-02-22  2025-03-22                   15
# 4            5  2025-01-31  2025-02-27                   15
# ...        ...         ...         ...                  ...
# 4995      4996  2025-02-24  2025-03-14                   10
# 4996      4997  2025-02-12  2025-03-02                    5
# 4997      4998  2025-02-14  2025-03-02                   20
# 4998      4999  2025-02-24  2025-03-26                   15
# 4999      5000  2025-02-26  2025-03-17                   20
#
#                                       Description   Price  \
# 0     Special offer available for a limited time!  110.40
# 1     Special offer available for a limited time!   77.35
# 2     Special offer available for a limited time!   65.70
# ...

# %%
offers_filled.to_excel("Integration/OfferWithImages.xlsx",index=False)

# %%
Businesses
# Out:
#      Restaurant ID    Restaurant Name          Category             City  \
# 0                1           30 North              Cafe       Alexandria
# 1                2             Indira     Asian Cuisine       Alexandria
# 2                3             Seoudi     Casual Dining            Cairo
# 3                4               Paul            Bakery       Alexandria
# 4                5              Wel3a             Grill  Sharm El Sheikh
# ..             ...                ...               ...              ...
# 995            996       Koshary Hend           Koshary             Giza
# 996            997        Abou Haidar        Sandwiches         Hurghada
# 997            998    Maison de Curry            Indian            Cairo
# 998            999           Arabiata  Egyptian Cuisine            Cairo
# 999           1000  Koshary El Tahrir           Koshary       Alexandria
#
#            Area  Longitude   Latitude  CategoryID  UserId  \
# ...

# %%
categoryImages = pd.read_excel("Integration/imagesByCategory.xlsx")
categoryImages
# Out:
#     CategoryID                                     ResturantImage
# 0            1  https://i.pinimg.com/736x/e6/66/27/e666274ae48...
# 1            1  https://i.pinimg.com/736x/b4/47/56/b44756941bd...
# 2            1  https://i.pinimg.com/736x/d9/90/19/d99019df843...
# 3            1  https://i.pinimg.com/736x/3b/a2/c5/3ba2c5ae61f...
# 4            2  https://i.pinimg.com/736x/63/07/d5/6307d54dc15...
# ..         ...                                                ...
# 91          23  https://i.pinimg.com/736x/7c/96/f6/7c96f62c84a...
# 92          24  https://i.pinimg.com/736x/a4/79/a2/a479a241085...
# 93          24  https://i.pinimg.com/736x/87/fb/d6/87fbd64f351...
# 94          24  https://i.pinimg.com/736x/5c/57/ee/5c57ee1e3c1...
# 95          24  https://i.pinimg.com/736x/df/33/7a/df337a53328...
#
# [96 rows x 2 columns]

# %%
result_df = Businesses.merge(categoryImages, on='CategoryID', how='left')

# %%
result_df
# Out:
#       Restaurant ID    Restaurant Name          Category        City  \
# 0                 1           30 North              Cafe  Alexandria
# 1                 1           30 North              Cafe  Alexandria
# 2                 1           30 North              Cafe  Alexandria
# 3                 1           30 North              Cafe  Alexandria
# 4                 2             Indira     Asian Cuisine  Alexandria
# ...             ...                ...               ...         ...
# 3995            999           Arabiata  Egyptian Cuisine       Cairo
# 3996           1000  Koshary El Tahrir           Koshary  Alexandria
# 3997           1000  Koshary El Tahrir           Koshary  Alexandria
# 3998           1000  Koshary El Tahrir           Koshary  Alexandria
# 3999           1000  Koshary El Tahrir           Koshary  Alexandria
#
#           Area  Longitude   Latitude  CategoryID  UserId  \
# 0        Gleem  29.901193  31.186937           1   10001
# ...

# %%
final = result_df[["Restaurant ID","ResturantImage"]]
final
# Out:
#       Restaurant ID                                     ResturantImage
# 0                 1  https://i.pinimg.com/736x/e6/66/27/e666274ae48...
# 1                 1  https://i.pinimg.com/736x/b4/47/56/b44756941bd...
# 2                 1  https://i.pinimg.com/736x/d9/90/19/d99019df843...
# 3                 1  https://i.pinimg.com/736x/3b/a2/c5/3ba2c5ae61f...
# 4                 2  https://i.pinimg.com/736x/63/07/d5/6307d54dc15...
# ...             ...                                                ...
# 3995            999  https://i.pinimg.com/736x/39/46/b3/3946b33c373...
# 3996           1000  https://i.pinimg.com/736x/41/d5/41/41d541da7bc...
# 3997           1000  https://i.pinimg.com/736x/d7/1a/0b/d71a0bcb35f...
# 3998           1000  https://i.pinimg.com/736x/aa/3e/f1/aa3ef1de8d5...
# 3999           1000  https://i.pinimg.com/736x/81/cf/94/81cf94c5291...
#
# [4000 rows x 2 columns]

# %%
final.to_excel("Integration/ImagesURL.xlsx",index=False)
